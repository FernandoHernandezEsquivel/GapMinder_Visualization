# %% [markdown]
# # Visualizaciones con la base de datos de Gapminder

# %% [markdown]
# ## Información sobre la base de datos

# %% [markdown]
# https://www.gapminder.org/

# %% [markdown]
# ### Importar la base de datos

# %% [markdown]
# "https://raw.githubusercontent.com/resbaz/r-novice-gapminder-files/master/data/gapminder-FiveYearData.csv"

# %%
import pandas as pd

# %%
gapminder_df=pd.read_csv("https://raw.githubusercontent.com/resbaz/r-novice-gapminder-files/master/data/gapminder-FiveYearData.csv")

# %%
gapminder_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   year       1704 non-null   int64
#  2   pop        1704 non-null   float64
#  3   continent  1704 non-null   object
#  4   lifeExp    1704 non-null   float64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 80.0+ KB

# %%
gapminder_df.describe(include="all")
# Out:
#             country        year           pop continent      lifeExp  \
# count          1704  1704.00000  1.704000e+03      1704  1704.000000
# unique          142         NaN           NaN         5          NaN
# top     Afghanistan         NaN           NaN    Africa          NaN
# freq             12         NaN           NaN       624          NaN
# mean            NaN  1979.50000  2.960121e+07       NaN    59.474439
# std             NaN    17.26533  1.061579e+08       NaN    12.917107
# min             NaN  1952.00000  6.001100e+04       NaN    23.599000
# 25%             NaN  1965.75000  2.793664e+06       NaN    48.198000
# 50%             NaN  1979.50000  7.023596e+06       NaN    60.712500
# 75%             NaN  1993.25000  1.958522e+07       NaN    70.845500
# max             NaN  2007.00000  1.318683e+09       NaN    82.603000
#
#             gdpPercap
# count     1704.000000
# unique            NaN
# top               NaN
# freq              NaN
# ...

# %%
gapminder_df.head()
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106

# %%
gapminder_df.tail()
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 1699  Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700  Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701  Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702  Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703  Zimbabwe  2007  12311143.0    Africa   43.487  469.709298

# %% [markdown]
# ### Renombrar las columnas a español

# %%
gapminder_df.columns=['pais', 'anio', 'poblacion', 'continente', 'esperanza_vida', 'PIB_per_capita']

# %%
gapminder_df.head()
# Out:
#           pais  anio   poblacion continente  esperanza_vida  PIB_per_capita
# 0  Afghanistan  1952   8425333.0       Asia          28.801      779.445314
# 1  Afghanistan  1957   9240934.0       Asia          30.332      820.853030
# 2  Afghanistan  1962  10267083.0       Asia          31.997      853.100710
# 3  Afghanistan  1967  11537966.0       Asia          34.020      836.197138
# 4  Afghanistan  1972  13079460.0       Asia          36.088      739.981106

# %%
gapminder_df.tail()
# Out:
#           pais  anio   poblacion continente  esperanza_vida  PIB_per_capita
# 1699  Zimbabwe  1987   9216418.0     Africa          62.351      706.157306
# 1700  Zimbabwe  1992  10704340.0     Africa          60.377      693.420786
# 1701  Zimbabwe  1997  11404948.0     Africa          46.809      792.449960
# 1702  Zimbabwe  2002  11926563.0     Africa          39.989      672.038623
# 1703  Zimbabwe  2007  12311143.0     Africa          43.487      469.709298

# %% [markdown]
# ## Gráficos con Seaborn

# %% [markdown]
# Recordemos que en seaborn tenemos dos tipos de syntaxis, gracias a que ha sido construida por encima de matplotlib podemos usar un formato de objeto-series, o mapear las variables a x o y, y poner el dataframe en el argumento de data=

# %%
import seaborn as sns

# %% [markdown]
# Usaremos el module warnings para ignorar las advertencias

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Histograma

# %% [markdown]
# Mapeando variables

# %%
_ = sns.histplot(x="esperanza_vida", data=gapminder_df)

# %% [markdown]
# Con series-object

# %%
_ = sns.histplot(gapminder_df.esperanza_vida)

# %% [markdown]
# Visualizar la distribución de la esperanza de vida por 1 año especifico

# %%
data_2007=gapminder_df[gapminder_df['anio'] == 2007]
_ = sns.histplot(data_2007.esperanza_vida)

# %% [markdown]
# ## Modificaciones más comunes a los gráficos con matplotlib o seaborn

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Incrementar el tamaño del Canvas

# %%
fig = plt.figure(figsize=(8, 8))
sns.set(rc = {'figure.figsize':(8,8)})

# %% [markdown]
# ### Controlar el color de las barras

# %%
_ = sns.histplot(gapminder_df.esperanza_vida, color='#ffff00')

# %%
_ = sns.histplot(gapminder_df.esperanza_vida, color='#98ff00')

# %% [markdown]
# ### Agregar etiquetas de los ejes y título

# %%
_ = sns.histplot(gapminder_df.esperanza_vida, color='#98ff00')
plt.title('Histograma de la esperanza de vida')
# Etiquetas del eje de las x's
plt.xlabel('Esperanza de vida')
# Etiquetas del eje de las y's
plt.ylabel('Frecuencia');

# %% [markdown]
# ### Modificar el límite de los ejes

# %%
_ = sns.histplot(gapminder_df.esperanza_vida, color='#98ff00')
plt.title('Histograma de la esperanza de vida')
# Etiquetas del eje de las x's
plt.xlabel('Esperanza de vida')
# Etiquetas del eje de las y's
plt.ylabel('Frecuencia')
# Modificando los ejes
plt.ylim(0, None)
plt.xlim(0, None);

# %%
_ = sns.histplot(gapminder_df.esperanza_vida, color='#98ff00')
plt.title('Histograma de la esperanza de vida')
# Etiquetas del eje de las x's
plt.xlabel('Esperanza de vida')
# Etiquetas del eje de las y's
plt.ylabel('Frecuencia')
# Modificando los ejes
plt.ylim(0, 240)
plt.xlim(23, 83);

# %% [markdown]
# ### Modificar el ancho de las barras

# %%
_ = sns.histplot(gapminder_df.esperanza_vida, color='#98ff00',binwidth=10)
plt.title('Histograma de la esperanza de vida')
# Etiquetas del eje de las x's
plt.xlabel('Esperanza de vida')
# Etiquetas del eje de las y's
plt.ylabel('Frecuencia')
# Modificando los ejes
plt.ylim(0, None)
plt.xlim(0, None);

# %%
_ = sns.histplot(gapminder_df.esperanza_vida, color='#98ff00',binwidth=3)
plt.title('Histograma de la esperanza de vida')
# Etiquetas del eje de las x's
plt.xlabel('Esperanza de vida')
# Etiquetas del eje de las y's
plt.ylabel('Frecuencia')
# Modificando los ejes
plt.ylim(0, None)
plt.xlim(0, None);

# %% [markdown]
# ### Agregar la leyenda al gráfico

# %%
chart = sns.histplot(gapminder_df.esperanza_vida, color='#98ff00',binwidth=10)
plt.title('Histograma de la esperanza de vida')
# Etiquetas del eje de las x's
plt.xlabel('Esperanza de vida')
# Etiquetas del eje de las y's
plt.ylabel('Frecuencia')
# Modificando los ejes
plt.ylim(0, None)
plt.xlim(0, None)
# Agregar la leyenda
plt.legend(['Esperanza de vida']);

# %% [markdown]
# ### Agregar etiquetas de los datos a las barras

# %% [markdown]
# Buscamos las etiquetas de cada barra

# %%
chart.patches

# %% [markdown]
# Buscamos la coordenada de x de la primera barra

# %%
chart.patches[0].get_x()
# Out:
# 23.599

# %% [markdown]
# Buscamos el ancho de la barra, el cual fue definido desde la función histplot

# %%
chart.patches[0].get_width()
# Out:
# 10.000000000000004

# %% [markdown]
# Buscamos el alto de la barra

# %%
chart.patches[0].get_height()
# Out:
# 18

# %%
chart = sns.histplot(gapminder_df.esperanza_vida, color='#98ff00', binwidth=10)
plt.title('Histograma de la esperanza de vida')
# Etiquetas del eje de las x's
plt.xlabel('Esperanza de vida')
# Etiquetas del eje de las y's
plt.ylabel('Frecuencia')
# Modificando los ejes
plt.ylim(0, None)
plt.xlim(0, None)
# Agregar la leyenda
plt.legend(['Esperanza de vida'])
# For loop para las anotaciones
for p in chart.patches:
            chart.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()),
            ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
            textcoords='offset points')

# %%
chart = sns.histplot(gapminder_df.esperanza_vida, color='#98ff00', binwidth=5)
plt.title('Histograma de la esperanza de vida')
# Etiquetas del eje de las x's
plt.xlabel('Esperanza de vida')
# Etiquetas del eje de las y's
plt.ylabel('Frecuencia')
# Modificando los ejes
plt.ylim(0, None)
plt.xlim(0, None)
# Agregar la leyenda
plt.legend(['Esperanza de vida'])
# For loop para las anotaciones
for p in chart.patches:
            chart.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()),
            ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
            textcoords='offset points')

# %% [markdown]
# ## Temas en seaborn

# %% [markdown]
# Los temas o estilos de seaborn son:
#    - white
#    - dark
#    - whitegrid
#    - darkgrid
#    - ticks

# %% [markdown]
# Vamos a probarlos

# %% [markdown]
# #### White

# %%
sns.set_style('white')
chart = sns.histplot(gapminder_df.esperanza_vida, color='#98ff00',binwidth=10)
plt.title('Histograma de la esperanza de vida')
# Etiquetas del eje de las x's
plt.xlabel('Esperanza de vida')
# Etiquetas del eje de las y's
plt.ylabel('Frecuencia')
# Modificando los ejes
plt.ylim(0, None)
plt.xlim(0, None)
# Agregar la leyenda
plt.legend(['Esperanza de vida'])
for p in chart.patches:
            chart.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()),
            ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
            textcoords='offset points')

# %% [markdown]
# #### Dark

# %%
sns.set_style('dark')
chart = sns.histplot(gapminder_df.esperanza_vida, color='#98ff00',binwidth=10)
plt.title('Histograma de la esperanza de vida')
# Etiquetas del eje de las x's
plt.xlabel('Esperanza de vida')
# Etiquetas del eje de las y's
plt.ylabel('Frecuencia')
# Modificando los ejes
plt.ylim(0, None)
plt.xlim(0, None)
# Agregar la leyenda
plt.legend(['Esperanza de vida'])
for p in chart.patches:
            chart.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()),
            ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
            textcoords='offset points')

# %% [markdown]
# #### Whitegrid

# %%
sns.set_style('whitegrid')
chart = sns.histplot(gapminder_df.esperanza_vida, color='#98ff00',binwidth=10)
plt.title('Histograma de la esperanza de vida')
# Etiquetas del eje de las x's
plt.xlabel('Esperanza de vida')
# Etiquetas del eje de las y's
plt.ylabel('Frecuencia')
# Modificando los ejes
plt.ylim(0, None)
plt.xlim(0, None)
# Agregar la leyenda
plt.legend(['Esperanza de vida'])
for p in chart.patches:
            chart.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()),
            ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
            textcoords='offset points')

# %% [markdown]
# #### Darkgrid

# %%
sns.set_style('darkgrid')
chart = sns.histplot(gapminder_df.esperanza_vida, color='#98ff00',binwidth=10)
plt.title('Histograma de la esperanza de vida')
# Etiquetas del eje de las x's
plt.xlabel('Esperanza de vida')
# Etiquetas del eje de las y's
plt.ylabel('Frecuencia')
# Modificando los ejes
plt.ylim(0, None)
plt.xlim(0, None)
# Agregar la leyenda
plt.legend(['Esperanza de vida'])
for p in chart.patches:
            chart.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()),
            ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
            textcoords='offset points')

# %% [markdown]
# #### Ticks

# %%
sns.set_style('ticks')
chart = sns.histplot(gapminder_df.esperanza_vida, color='#98ff00',binwidth=10)
plt.title('Histograma de la esperanza de vida')
# Etiquetas del eje de las x's
plt.xlabel('Esperanza de vida')
# Etiquetas del eje de las y's
plt.ylabel('Frecuencia')
# Modificando los ejes
plt.ylim(0, None)
plt.xlim(0, None)
# Agregar la leyenda
plt.legend(['Esperanza de vida']);
for p in chart.patches:
            chart.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()),
            ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
            textcoords='offset points')

# %% [markdown]
# ### Para visualizarlos mejor organicémoslos en una cuadrícula de 2x2 usando la función subplots

# %%
fig, axes = plt.subplots(2, 2)

sns.set_style('darkgrid')
sns.histplot(gapminder_df.esperanza_vida, color='#98ff00',  ax=axes[0, 0],binwidth=3)
plt.xticks(color='w')

sns.histplot(gapminder_df.esperanza_vida, color='#98ff00', ax=axes[0, 1],binwidth=6)

sns.histplot(gapminder_df.esperanza_vida, color='#98ff00', ax=axes[1, 0],binwidth=9)

sns.histplot(gapminder_df.esperanza_vida, color='#98ff00', ax=axes[1, 1],binwidth=12)

axes[0, 0].set_title("binwidth=3")
axes[0, 1].set_title("binwidth=6")
axes[1, 0].set_title("binwidth=9")
axes[1, 1].set_title("binwidth=12")

fig.tight_layout(pad=3.0)

# %% [markdown]
# ## Gráfico de barras o countplot

# %%
gapminder_df.groupby('continente', as_index=False)['esperanza_vida'].count()
# Out:
#   continente  esperanza_vida
# 0     Africa             624
# 1   Americas             300
# 2       Asia             396
# 3     Europe             360
# 4    Oceania              24

# %% [markdown]
# ### Countplot

# %%
sns.countplot(x="continente", data=gapminder_df);

# %% [markdown]
# ## Exportar gráficos a la ruta en formato .png y .pdf

# %%
sns.countplot(x="continente", data=gapminder_df)
plt.savefig("countplot1.png")
plt.savefig("countplot1.pdf")

# %% [markdown]
# ## Paletas de colores pre-determinadas por el usuario

# %%
# Paleta en formato HEX
mi_paleta = ['#78C850',   
            '#F08030', 
            '#6890F0',   
            '#A8B820', 
            '#A8A878']

# %%
sns.countplot(x="continente", data=gapminder_df, palette=mi_paleta);

# %% [markdown]
# ### Girar las estiquetas de los datos del eje de las X´s

# %%
sns.countplot(x="continente", data=gapminder_df, palette=mi_paleta)
# Rota las etiquetas del eje de las x's
plt.xticks(rotation=45);

# %% [markdown]
# ## Distribuciones unidimensionales

# %% [markdown]
# ### Diagrama de caja y bigotes

# %%
sns.boxplot(y="esperanza_vida", data=gapminder_df);

# %% [markdown]
# ### Agregamos observaciones reales al gráfico, esto funciona con los demás gráficos, como un violinplot, etc.

# %%
sns.boxplot(y="esperanza_vida", data=gapminder_df)
sns.swarmplot(y='esperanza_vida', data=gapminder_df, 
              color='k', # Hace los puntos negros
              alpha=0.7); # Nivel de transparencia

# %% [markdown]
# #### Cambiando el color del Boxplot

# %%
sns.boxplot(y="esperanza_vida", data=gapminder_df, color='lightblue')
sns.swarmplot(y='esperanza_vida', data=gapminder_df, color='k', alpha=0.7);

# %% [markdown]
# ## Aumentando el eje de las x's y creando una lista ordenada de las categorias

# %%
lista_continentes = sorted(list(set(gapminder_df.continente)))
lista_continentes
# Out:
# ['Africa', 'Americas', 'Asia', 'Europe', 'Oceania']

# %%
sns.boxplot(x="continente", y="esperanza_vida", order=lista_continentes, data=gapminder_df);

# %% [markdown]
# ### Gráfico de densidad

# %%
sns.set_style('white')
sns.distplot(gapminder_df.esperanza_vida);

# %% [markdown]
# ## Líneas y scatterplots o gráficos de dispersión

# %%
sns.set_style('white')
sns.scatterplot(x="PIB_per_capita",y="esperanza_vida",hue='continente',data=gapminder_df);

# %% [markdown]
# ### Se puede utilizar el comando alterno: lmplot() que además de un scatterplot aumentará una línea de regresión lineal al gráfico para tener una idea de su ajuste

# %%
sns.set_style('white')
sns.lmplot(x='PIB_per_capita', y='esperanza_vida', hue='continente', data=gapminder_df);

# %% [markdown]
# ### Para modificar este gráfico y volver a un gráfico de dispersión. Por ejemplo podemos utilizar el argumento fit_reg=False para omitir la línea de regresión lineal

# %%
sns.lmplot(x='PIB_per_capita', y='esperanza_vida',
           hue='continente', data=gapminder_df, fit_reg=False);

# %% [markdown]
# ### Filtrando en el gráfico

# %%
sns.scatterplot(x="PIB_per_capita",y="esperanza_vida",data= gapminder_df[gapminder_df.pais=="Mexico"]);

# %% [markdown]
# ### Agregando el gráfico de línea al de dispersión

# %%
sns.lineplot(x="PIB_per_capita",y="esperanza_vida",data= gapminder_df[gapminder_df.pais=="Mexico"])
sns.scatterplot(x="PIB_per_capita",y="esperanza_vida",data= gapminder_df[gapminder_df.pais=="Mexico"]);

# %% [markdown]
# ### Agregar variables al gráfico

# %% [markdown]
# ¿Cómo podemos mostrar más variables si sólo trabajamos en dos dimensiones?
# - Haciendo uso de las formas y tamaños es posible mostrar más variables aún en dos dimensiones

# %%
sns.scatterplot(x='PIB_per_capita',y='esperanza_vida',data=gapminder_df[gapminder_df['anio'] == 2007],hue='continente',
                size='poblacion');

# %% [markdown]
# ### Lineplot por continente

# %%
sns.lineplot(x="anio",y="esperanza_vida",hue="continente",data= gapminder_df);

# %% [markdown]
# ### Graficando la esperanza de vida a través del cálculo de su mediana por año y continente, desaparece el intervalo en el gráfico

# %%
sns.lineplot(x="anio",y="esperanza_vida",hue="continente",
             data= gapminder_df.groupby(['continente','anio']).esperanza_vida.median().reset_index());

# %% [markdown]
# ### Separando el gráfico por continente

# %%
sns.relplot(x="anio",y="esperanza_vida",hue="continente",
             data= gapminder_df.groupby(['continente','anio']).esperanza_vida.median().reset_index(),
            col="continente", height=10, aspect=0.5,kind="line");

# %% [markdown]
# ### Cambiando el tipo de línea

# %%
sns.relplot(x="anio",y="esperanza_vida",hue="continente",
             data= gapminder_df.groupby(['continente','anio']).esperanza_vida.median().reset_index(),
            col="continente", height=10, aspect=0.5,kind="scatter");

# %% [markdown]
# ### Factor plots

# %% [markdown]
# Es la forma más fácil para graficar categorías

# %% [markdown]
# Tipos de gráficos que acepta: “point”, “bar”, “strip”, “swarm”, “box”, “violin”, or “boxen”.

# %% [markdown]
# ### Point

# %%
g = sns.factorplot(x='anio',y='esperanza_vida',data=gapminder_df, 
                   hue='continente',
                   col='continente',  
                   kind='point',
                   height=7, aspect=0.8)

# %% [markdown]
# ### Bar

# %%
g = sns.factorplot(x='anio', 
                   y='esperanza_vida', 
                   data=gapminder_df, 
                   hue='continente',
                   col='continente', 
                   kind='bar',
                  height=7, aspect=0.8)

# %% [markdown]
# ### Strip

# %%
g = sns.factorplot(x='anio', 
                   y='esperanza_vida', 
                   data=gapminder_df, 
                   hue='continente',
                   col='continente', 
                   kind='strip',
                  height=7, aspect=0.8)

# %% [markdown]
# ### Swarm

# %%
g = sns.factorplot(x='anio', 
                   y='esperanza_vida', 
                   data=gapminder_df, 
                   hue='continente',
                   col='continente', 
                   kind='swarm',
                  height=7, aspect=0.8)

# %% [markdown]
# ### Box

# %%
g = sns.factorplot(x='anio', 
                   y='esperanza_vida', 
                   data=gapminder_df, 
                   hue='continente',
                   col='continente', 
                   kind='box',
                  height=7, aspect=0.8)

# %% [markdown]
# ### Violin

# %%
g = sns.factorplot(x='anio', 
                   y='esperanza_vida', 
                   data=gapminder_df, 
                   hue='continente',
                   col='continente', 
                   kind='violin',
                  height=7, aspect=0.8)

# %% [markdown]
# ### Boxen

# %%
g = sns.factorplot(x='anio', 
                   y='esperanza_vida', 
                   data=gapminder_df, 
                   hue='continente',
                   col='continente', 
                   kind='boxen',
                  height=7, aspect=0.8)

# %% [markdown]
# ## Gráficos de 2 variables

# %% [markdown]
# ### Joint distribution plot

# %%
sns.jointplot(x='PIB_per_capita', y='esperanza_vida', data=gapminder_df);

# %% [markdown]
# ### Cambiando el tamaño

# %%
sns.jointplot(x='PIB_per_capita', y='esperanza_vida', data=gapminder_df ,height=10);

# %% [markdown]
# ### Aplicando logaritmo a la variable del PIB_per_capita para visualizar de mejor manera

# %%
import numpy as np

# %%
gapminder_df['log_PIB_per_caapita']=np.log(gapminder_df.PIB_per_capita)

# %%
sns.jointplot(x='log_PIB_per_caapita', y='esperanza_vida', data=gapminder_df ,height=10);

# %% [markdown]
# ## FacetGrid con la función displot

# %% [markdown]
# ### Con histograma

# %%
g = sns.FacetGrid(gapminder_df, row="continente", row_order=lista_continentes,
                  height=2, aspect=4)
g.map(sns.distplot, "esperanza_vida", hist=True);

# %% [markdown]
# ### Sin histograma

# %%
g = sns.FacetGrid(gapminder_df, row="continente", row_order=lista_continentes,
                  height=2, aspect=4)
g.map(sns.distplot, "esperanza_vida", hist=False);

# %% [markdown]
# ### En un solo gráfico

# %%
g = sns.FacetGrid(gapminder_df, hue="continente",height=5, aspect=2)
g.map(sns.distplot, "esperanza_vida", hist=False)
g.add_legend();

# %% [markdown]
# ## Correlaciones lineales

# %% [markdown]
# Primero se calculan las correlaciones

# %%
corr = gapminder_df.corr()

# %% [markdown]
# A partir de las correlaciones calculadas se grafican estas por medio de la función heatmap

# %%
sns.heatmap(corr,annot=True);

# %% [markdown]
# ### Cambiando la paleta de color

# %%
sns.heatmap(corr,annot=True,cmap="YlGnBu");

# %%
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
  f, ax = plt.subplots(figsize=(8, 8))
  sns.heatmap(corr,annot=True,mask=mask,vmax=.3,square=True)

# %%
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
  f, ax = plt.subplots(figsize=(8, 8))
  sns.heatmap(corr,annot=True,cmap="YlGnBu",mask=mask,vmax=.3,square=True)

# %% [markdown]
# ## Gráficos avanzados con plotly

# %%
import plotly
import plotly.express as px

# %%
gapminder_df.anio
# Out:
# 0       1952
# 1       1957
# 2       1962
# 3       1967
# 4       1972
#         ...
# 1699    1987
# 1700    1992
# 1701    1997
# 1702    2002
# 1703    2007
# Name: anio, Length: 1704, dtype: int64

# %%
fig = px.scatter(
    data_frame=gapminder_df[gapminder_df['anio'] == 2007], 
    x="PIB_per_capita", 
    y="esperanza_vida", 
    size="poblacion", 
    color="continente",
    hover_name="pais",
    size_max=60
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Animaciones

# %% [markdown]
# ### Tomando el logaritmo del PIB_per_capita

# %%
fig = px.scatter(
    data_frame=gapminder_df, 
    x="log_PIB_per_caapita", 
    y="esperanza_vida", 
    animation_frame="anio", 
    size="poblacion", 
    color="continente", 
    hover_name="pais", 
    facet_col="continente",
    size_max=45,
    category_orders={'Anio':list(range(1952,2007,5))}     
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
